# %% [markdown]
# # Exercise - Visualization of Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from the AutoMPG dataset file. Assign it to a variable called mpg_df

# %%
mpg_df=pd.read_csv("auto-mpg.csv")

# %% [markdown]
# ### Step 3. Perform basic EDA to understand the structure of the data

# %%
mpg_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg_df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
mpg_df.shape
# Out:
# (398, 9)

# %%
mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
mpg_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ### Step 4. Check and handle the missing values, if any.

# %%
mpg_df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# ### Step 5. Create a plot to check the relationship between horsepower and acceleration. Note down your insight for the same. Beautify the graph using various customizations.

# %%
sns.relplot(x='horsepower',y='acceleration',data=mpg_df,color='r',aspect=6)

# %% [markdown]
# ### Step 6. Generate subplots to display the histograms for acceleration, displacement and weight and kilometer_per_litre. Note down your insight for the same

# %%
plt.subplot(2,2,1)
plt.title('accleration')
plt.hist(mpg_df.acceleration,color="r",label='displacement')
plt.subplot(2,2,2)
plt.title('displacement')

plt.hist(mpg_df.displacement,color='g')

plt.subplot(2,2,3)

plt.title('weight')

plt.hist(mpg_df.weight,color='y')
plt.subplot(2,2,4)
plt.title('Mpg')

plt.hist(mpg_df.mpg)
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Step 7. Create a plot to check the relationship between displacement and weight for origin 2, color the datapoints based on no of cylinders. Note down your insight for the same and save the plot as an image file.

# %%
mpg=mpg_df[mpg_df.origin==2]
sns.relplot(x="displacement", y="weight",hue = "cylinders", data = mpg)

# %% [markdown]
# ### Step 8. Display the frequency distribution of the Origin variable. Note down your insight for the same

# %%
sns.countplot(mpg_df.origin)
# Out:
# C:\Users\sanke\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %% [markdown]
# ### Step 9. Check the relationship of multiple variables wrt kilometer_per_litre. Note down your insight for the same

# %%
sns.pairplot(data=mpg_df,
                  x_vars=['mpg'],
                  y_vars=['cylinders', 'displacement', 'acceleration','model year','origin','weight'],kind='hist')

# %% [markdown]
# ### Step 10. Display the average weight based on no of cylinders present. Note down the insight for the same

# %%
mpg1=(mpg_df.groupby(by=mpg_df.cylinders)).mean()
sns.relplot(x='cylinders',y='weight',data=mpg1,kind='line',markers=True)

# %% [markdown]
# ### Step 11. Check for the outliers in the dataset. Note down the insight for the same.

# %%
sns.boxplot(data=mpg_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 12. Plot the correlations for variables.

# %%
sns.heatmap(mpg_df.corr())
# Out:
# <AxesSubplot:>
